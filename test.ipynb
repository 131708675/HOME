# %%
import matplotlib.pyplot as plt   
import pandas as pd

# %%
def plot_variable_pie(data_table, variable):  
    pass  # 你的代码逻辑

# %%
import matplotlib.pyplot as plt  
  
fig, ax = plt.subplots() # Use plt.subplots() to create a figure and a subplot  
# 如果 data 是字典，假设我们想要绘制的是字典的键对应的值  
ax.pie(list(data.values()),labels=list(data.keys()),autopct='%1.1f%%')    
plt.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.
# Out:
# (-1.0999990089477236,
#  1.0999999528070346,
#  -1.0999916372938978,
#  1.0999916372938978)

# %%
pip install mymodule
# Out:
# ...
# Using legacy 'setup.py install' for mymodule, since package 'wheel' is not installed.
# ...
#     Running setup.py install for mymodule: started
#     Running setup.py install for mymodule: finished with status 'done'
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.1; however, version 23.3.1 is available.
# You should consider upgrading via the 'c:\Users\Lenovo\AppData\Local\Programs\Python\Python38\python.exe -m pip install --upgrade pip' command.
